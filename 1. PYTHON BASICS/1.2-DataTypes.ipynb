# %%
# integer example

age = 22
type(age)
# Out:
# int

# %%
# floating point data type
height = 5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
# string
name = "sonam"
print(name)
print(type(name))
# Out:
# sonam
# <class 'str'>

# %%
# boolean
is_true = True
type(is_true)
# Out:
# bool
