# %%
# infinite loop
i = 1

while i <= 5:
    print(i)


# correct code
i = 1

while i <= 5:
    print(i)
    i += 1

# %%
for i in range(1, 5):
    print(i)


# correct
range(1, 6)
# Out:
# 1
# 2
# 3
# 4

# %%
# wrong
for i in range(5):
print(i)


# right
for i in range(5):
    print(i)
# Out:
#   Cell In[4], line 3
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
for i in range(5):
    continue
    print(i)
