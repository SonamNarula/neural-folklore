# %%
if age >= 18
    print("Eligible")
# Out:
#   Cell In[1], line 1
#     if age >= 18
#                 ^
# SyntaxError: expected ':'

# %%
if age >= 18:
print("Eligible")
# Out:
#   Cell In[2], line 2
#     print("Eligible")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if age >= 18:
    print("Eligible")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 if age >= 18:
#       2     print("Eligible")
#
# NameError: name 'age' is not defined

# %%
if age = 18:
# Out:
#   Cell In[4], line 1
#     if age = 18:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
if age == 18:
# Out:
#   Cell In[5], line 1
#     if age == 18:
#                  ^
# _IncompleteInputError: incomplete input

# %%
elif:
    print("Hello")
# Out:
#   Cell In[6], line 1
#     elif:
#     ^
# SyntaxError: invalid syntax

# %%
elif age >= 18:
    print("Hello")
# Out:
#   Cell In[7], line 1
#     elif age >= 18:
#     ^
# SyntaxError: invalid syntax

# %%
marks = 95

if marks >= 50:
    print("Pass")
elif marks >= 90:
    print("Excellent")
# Out:
# Pass

# %%
if marks >= 90:
    print("Excellent")
elif marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Excellent

# %%
if condition:
    statement
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 if condition:
#       2     statement
#
# NameError: name 'condition' is not defined

# %%
if age >= 18 and age <= 60:
# Out:
#   Cell In[11], line 1
#     if age >= 18 and age <= 60:
#                                ^
# _IncompleteInputError: incomplete input

# %%
if age >= 18:
    if has_id:
        if valid:
            print("Allowed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 if age >= 18:
#       2     if has_id:
#       3         if valid:
#       4             print("Allowed")
#
# NameError: name 'age' is not defined

# %%
if age >= 18 and has_id and valid:
    print("Allowed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 if age >= 18 and has_id and valid:
#       2     print("Allowed")
#
# NameError: name 'age' is not defined

# %%
if marks >= 90:
    print("A")
elif marks >= 80:
    print("B")
elif marks >= 70:
    print("C")
else:
    print("D")
# Out:
# A
