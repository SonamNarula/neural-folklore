# %%
# Dictionary stores data as:
# key : value

student = {
    "name": "Sonam",
    "age": 21,
    "branch": "CSE"
}

print(student)
print(type(student))
# Out:
# {'name': 'Sonam', 'age': 21, 'branch': 'CSE'}
# <class 'dict'>
