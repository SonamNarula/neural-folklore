# %%
def function(parameter):
    """Docstring"""
    # Function body
    return expression

# %%
# why functions
num = 24
if num%2==0:
    print("the no is even")
else:
    print("the no is odd")
# Out:
# the no is even

# %%
def even_or_odd(num) :
    """"this function finds even or odd"""
    if num%2==0:
        print("the no is even")
    else:
        print("the no is odd")

# %%
# call this function
even_or_odd(24)
# Out:
# the no is even

# %%
# function with multiple parameters
def add(a,b) :
    return a+b
result = add(2,4)
print(result)
# Out:
# 6

# %%
# default parameters

def greet(name):
    print(f"hello {name}, its time for you to start working hard coz you have to shine in germany before aug 2027")
greet("sonam narula")
# Out:
# hello sonam narula its time for you to start working hard coz you have to shine in germany before aug 2027

# %%
# default parameters

def greet(name):
    print(f"hello {name}, its time for you to start working hard coz you have to shine in germany before aug 2027")
greet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       1 # default parameters
#       2
#       3 def greet(name):
#       4     print(f"hello {name}, its time for you to start working hard coz you have to shine in germany before aug 2027")
# ----> 5 greet()
#
# TypeError: greet() missing 1 required positional argument: 'name'

# %%
# default parameters

def greet(name = "sonam narula"):
    print(f"hello {name}, its time for you to start working hard coz you have to shine in germany before aug 2027")
greet()
# Out:
# hello sonam narula, its time for you to start working hard coz you have to shine in germany before aug 2027

# %%
# variable length arguments
# positional and keywords arguments

def print_numbers(*sonam):
    for numbers in sonam:
        print(number)
