# %%
def function(parameter):
    """Docstring"""
    # Function body
    return expression

# %%
# why functions
num = 24
if num%2==0:
    print("the no is even")
else:
    print("the no is odd")
# Out:
# the no is even
