# %%
a = 100

# %%
# declaring and assigning variables

age = 32
height = 6.1
name = "Sonam"
is_student = True

# printing the variables
print("age :", age)
print("height :", height)
print("name :", name)

# %%
# naming conventions
# variable names should be descriptive
# they must start with a letter or an '_' and contains letter, numbers and underscores
# variable name are case sensitive

# valid variable names

first_name = "sonam"
last_name = "narula"

# %%
# understanding variable types
# python is dynamically typed

age = 25
height = 6.1
name = "sonam"
is_student = True

print(type(name))
print(type(height))
# Out:
# <class 'str'>
# <class 'float'>

# %%
age = 25
print(type(age))

# type conversion
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age = 25
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name = "Sonam"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 name = "Sonam"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Sonam'

# %%
height = 5.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
# dynamic typing
var = 10
print(var, type(var))
# Out:
# 10 <class 'int'>

# %%
var = "hello"
print(var, type(var))
# Out:
# hello <class 'str'>

# %%
var=3.14
print(var, type(var))
# Out:
# 3.14 <class 'float'>

# %%
# input
age = input("what is the age")
print(age, type(age))
